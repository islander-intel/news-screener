# %%
import yfinance as yf

# %%
appl = yf.Ticker("MSFT")

# %%
for i in appl.info:
    if i =="floatShares":
        print(i)
# Out:
# floatShares

# %%
appl.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software—Infrastructure',
#  'industryDisp': 'Software—Infrastructure',
#  'sector': 'Technology',
#  'sectorDisp': 'Technology',
# ...

# %%
with open("data/all syms", "r") as file:
    for i in file.readlines():
        print(i)
# Out:
# A
#
# AA
#
# AAAU
#
# AACG
#
# AADR
#
# AAL
#
# AAMC
#
# AAME
#
# AAN
#
# AAOI
#
# AAON
#
# AAP
#
# AAPL
#
# AAT
#
# AAU
#
# AAWW
#
# AAXJ
#
# AAXN
#
# AB
#
# ABB
#
# ABBV
#
# ABC
#
# ABCB
#
# ABEO
#
# ABEQ
#
# ABEV
#
# ABG
#
# ABIO
#
# ABM
#
# ABMD
#
# ABR
#
# ABT
#
# ABTX
#
# ABUS
#
# AC
#
# ACA
#
# ACAD
#
# ACAM
#
# ACAMU
#
# ACAMW
#
# ACB
#
# ACBI
#
# ACC
#
# ACCO
#
# ACE-W
#
# ACEL
#
# ACER
#
# ACES
#
# ACGL
#
# ACGLO
#
# ACGLP
#
# ACH
#
# ACHC
#
# ACHV
#
# ACI
#
# ACIA
#
# ACIO
#
# ACIU
#
# ACIW
#
# ACLS
#
# ACM
#
# ACMR
#
# ACN
#
# ACNB
#
# ACOR
#
# ACP
#
# ACRE
#
# ACRS
#
# ACRX
#
# ACSG
#
# ACSI
#
# ACST
#
# ACT
#
# ACTG
#
# ACTT
#
# ACTTU
#
# ACTTW
#
# ACU
#
# ACV
#
# ACWF
#
# ACWI
#
# ACWV
#
# ACWX
#
# ACY
#
# ADAP
#
# ADBE
#
# ADC
#
# ADCT
#
# ADES
#
# ADI
#
# ADIL
#
# ADILW
#
# ADM
#
# ADMA
#
# ADME
#
# ADMP
#
# ADMS
#
# ADNT
#
# ADP
#
# ADPT
#
# ADRE
#
# ADRO
#
# ADS
#
# ADSK
#
# ADSW
#
# ADT
#
# ADTN
#
# ADTX
#
# ADUS
#
# ADVM
#
# ADX
#
# ADXN
#
# ADXS
#
# AE
#
# AEB
# ...

# %%
import pandas as pd
origin = pd.read_csv("stock_origin.csv")

# %%
final_columns = ['Symbol', 'Name','Country','Sector', 'Industry']

# %%
# index_1 = index_1.iloc[:,:].values
# index_2 = index_2.iloc[:,:].values
# index_3 = index_3.iloc[:,:].values
# index_1.shape,index_2.shape,index_3.shape

# %%
drop_list = [i for i in origin.columns if i not in final_columns]

# %%
origin.drop_duplicates(inplace=True)

# %%
origin.drop(columns=drop_list,inplace=True)
origin.to_csv("all tickers.csv",index=False)

# %%
origin.to_csv("all tickers.csv",index=False)

# %%
from os.path import join
names = {'Symbol':[i.strip() for i in origin.Symbol if isinstance(i,str) and "^" not in i and "/" not in i]}
pd.DataFrame(names).to_csv(join("data","all tickers.csv"),index=False)

# %%
origin.dropna(inplace=True)

# %%
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7517 entries, 0 to 10425
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Symbol    7516 non-null   object
#  1   Name      7517 non-null   object
#  2   Country   7091 non-null   object
#  3   Sector    6867 non-null   object
#  4   Industry  6867 non-null   object
# dtypes: object(5)
# memory usage: 352.4+ KB

# %%
index_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2122 entries, 0 to 2908
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Symbol    2122 non-null   object
#  1   Name      2122 non-null   object
#  2   Country   2122 non-null   object
#  3   Sector    2122 non-null   object
#  4   Industry  2122 non-null   object
# dtypes: object(5)
# memory usage: 99.5+ KB

# %%
final = {}
for i in final_columns:
    final[i]=list(index_1[i])

# %%
index_3 = index_3.to_dict()

# %%
for columns in index_3.keys():
    for data in index_3[columns]:
        final[columns].append(data)

# %%
len(final["Symbol"])
# Out:
# 10727

# %%
final = pd.DataFrame(final,columns=final_columns)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10727 entries, 0 to 10726
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Symbol    10727 non-null  object
#  1   Name      10727 non-null  object
#  2   Country   10727 non-null  object
#  3   Sector    10727 non-null  object
#  4   Industry  10727 non-null  object
# dtypes: object(5)
# memory usage: 419.1+ KB

# %%
# drop_index =[]
# temp = []
# sym = final.iloc[:,0].values
# print(sym.shape)
# for index,val in enumerate(sym):
#     print(index)
#     # if val in temp:
#     #     drop_index.append(index)
#     # else:
#     #     temp.append(val)
final.drop_duplicates()
# Out:
#      Symbol                                               Name        Country  \
# 0         A             Agilent Technologies Inc. Common Stock  United States
# 1        AA                    Alcoa Corporation Common Stock   United States
# 2      AAIC      Arlington Asset Investment Corp Class A (new)  United States
# 3      AAIN  Arlington Asset Investment Corp 6.000% Senior ...  United States
# 4       AAN         Aarons Holdings Company Inc. Common Stock   United States
# ...     ...                                                ...            ...
# 8600   7512                                               7512           7512
# 8601   7513                                               7513           7513
# 8602   7514                                               7514           7514
# 8603   7515                                               7515           7515
# 8604   7516                                               7516           7516
#
# ...

# %%
import pandas as pd
data = pd.read_csv("data/names.csv")

# %%
# for i in data.iloc[:,0].values:
#     if isinstance(i,str) and "^" in i:
#         print(i)
    # print(type(i))
    names
# Out:
#   Input In [1]
#     names
#     ^
# IndentationError: unexpected indent

# %%
import sys
sys.path.insert(0,"/Users/williammckeon/Desktop/news-screener/src")
from updating_data import identitfing_tickers
data = identitfing_tickers("data/all tickers.csv")
data.data

# %%
# for i in data.data.keys():
#     # print(f"{i}:{len
data.data.keys()
# Out:
# dict_keys(['address1', 'address2', 'city', 'state', 'zip', 'country', 'phone', 'website', 'industry', 'industryDisp', 'sector', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate', 'dividendYield', 'exDividendDate', 'beta', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesS
# ...

# %%
import yfinance as yf
data = yf.Ticker("APPL")

# %%
data.info
# Out:
# {'exchange': 'YHD',
#  'quoteType': 'MUTUALFUND',
#  'symbol': 'APPL',
#  'underlyingSymbol': 'APPL',
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'fc74d387-06b2-3b3b-9d2b-a67dd39f76c4',
#  'gmtOffSetMilliseconds': -14400000,
#  'maxAge': 86400,
#  'trailingPegRatio': None}
