# %%
import pandas as pd
from os.path import join
import sys
import yfinance as yf
sys.path.insert(0,"/Users/williammckeon/Desktop/news-screener/src")
from updating_data import identitfing_tickers
origin = pd.read_csv("stock_origin.csv")
final_columns = ['Symbol', 'Name','Country','Sector', 'Industry']
drop_list = [i for i in origin.columns if i not in final_columns]
origin.drop_duplicates(inplace=True)
origin.drop(columns=drop_list,inplace=True)
drop_index = [index for index in origin.Symbol.index if isinstance(origin.Symbol[index],str) and "^" in origin.Symbol[index] or isinstance(origin.Symbol[index],str) and "/" in origin.Symbol[index] or isinstance(origin.Symbol[index],float)]
origin.drop(drop_index, inplace = True)
origin.dropna(inplace = True)
# names = origin.iloc[:,0].values
# float_vales = []
# count = 0
# for i in names:
#     data = yf.Ticker(i)
#     if "floatShares" in data.info.keys():
#         # print("yes")
#         val = data.info["floatShares"]
#         print(val)
#     else:
#         val = None
#     float_vales.append(val)
#     if count == 10:
#         break
#     else:
#         count+=1
origin.to_csv(join("data","final.csv"),index=False)
data = identitfing_tickers("data/final.csv",nrows=200)
data.data.dropna(inplace=True)
# for i in data["floate shares"].index:
#     if data["floate shares"][i]:
#         print(data.Symbol[i])
# Out:
#     Symbol                                               Name        Country  \
# 0        A             Agilent Technologies Inc. Common Stock  United States
# 1       AA                    Alcoa Corporation Common Stock   United States
# 2     AAIC      Arlington Asset Investment Corp Class A (new)  United States
# 3     AAIN  Arlington Asset Investment Corp 6.000% Senior ...  United States
# 4      AAN         Aarons Holdings Company Inc. Common Stock   United States
# ..     ...                                                ...            ...
# 195   BALY                   Bally's Corporation Common Stock  United States
# 196   BANC               Banc of California Inc. Common Stock  United States
# 197    BAP                        Credicorp Ltd. Common Stock           Peru
# 198    BAX             Baxter International Inc. Common Stock  United States
# 199     BB                    BlackBerry Limited Common Stock         Canada
#
#                      Sector                                          Industry  \
# 0               Industrials  Biotechnology: Laboratory Analytical Instruments
# 1               Industrials                                          Aluminum
# 2               Real Estate                     Real Estate Investment Trusts
# 3               Real Estate                     Real Estate Investment Trusts
# 4    Consumer Discretionary                   Diversified Commercial Services
# ..                      ...                                               ...
# 195  Consumer Discretionary                                    Hotels/Resorts
# 196                 Finance                                       Major Banks
# 197                 Finance                                  Commercial Banks
# 198             Health Care                        Medical/Dental Instruments
# 199              Technology           Computer Software: Prepackaged Software
#
#      float shares
# 0     292038960.0
# 1     177027362.0
# 2      27060174.0
# 3             NaN
# 4      30017948.0
# ..            ...
# 195    28503275.0
# 196    52545524.0
# 197    52587715.0
# 198   504698243.0
# 199           NaN
#
# [200 rows x 6 columns]

# %%
# floa_shares = (input("enter the float value you want the stocks to have less then or equal to"))*(10**6)
# country = "United States"
import pandas as pd
import numpy as np
tickers = pd.read_csv("ticker_info.csv")
User_filter = {"float shares":(input("enter the float value you want the stocks to have less then or equal to")),
"Country":"United States",
"Sector":"Technology",
"Industry":"",}
user_dataset = {"Symbol":[], "Name":[],
"Country":[],
"Sector":[],
"Industry":[],
"float shares":[]
}
if User_filter["float shares"] =="":
    User_filter["float shares"] = tickers["float shares"].max()
else:
    User_filter["float shares"] = float(User_filter["float shares"])*(10**6)
for index,val in enumerate(tickers["float shares"]):
    if val<=User_filter["float shares"] and val !=float("nan"):
        for key in user_dataset.keys():
            user_dataset[key].append(tickers[key][index])
for col in ["Country","Sector","Industry"]:
    if User_filter[col]!="":
        temp = {"Symbol":[], "Name":[],
        "Country":[],
        "Sector":[],
        "Industry":[],
        "float shares":[]
        }
        for index,val in enumerate(user_dataset[col]):
            if val == User_filter[col]:
                for key in user_dataset.keys():
                    temp[key].append(user_dataset[key][index])
        user_dataset = temp
user_dataset = pd.DataFrame(user_dataset)
# yf.tickers()
period = "15mn"
want = 0
user_dataset
import yfinance as yf
vol = []
for tick in user_dataset["Symbol"]:
    try:
        vol.append(yf.Ticker(tick).history(period="15mn")["Volume"][0])
    except:
        vol.append(float("nan"))
user_dataset["Volume"] = vol
user_dataset.dropna(inplace=True)
user_dataset.sort_values(by=["Volume"],ascending=False,inplace=True)
# user_data = data.data.filter(items = "United States")
# Out:
# AOGO: Period '15mn' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']
# FGMCU: Period '15mn' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']

# %%
user_dataset
# Out:
#     Symbol                                               Name        Country  \
# 42    CRKN           Crown Electrokinetics Corp. Common Stock  United States
# 143   UTRS                 Minerva Surgical Inc. Common Stock  United States
# 136   TMPO        Tempo Automation Holdings Inc. Common Stock  United States
# 6       UI                         Ubiquiti Inc. Common Stock  United States
# 101    OIG     Orbital Infrastructure Group Inc. Common Stock  United States
# ..     ...                                                ...            ...
# 96    NSYS          Nortech Systems Incorporated Common Stock  United States
# 139   TSRI                              TSR Inc. Common Stock  United States
# 12    ALOT                        AstroNova Inc. Common Stock  United States
# 66     GSD  Global Systems Dynamics Inc. Class A Common Stock  United States
# 149   WAVS    Western Acquisition Ventures Corp. Common Stock  United States
#
#          Sector                                           Industry  \
# 42   Technology                    Industrial Machinery/Components
# 143  Technology            Computer Software: Prepackaged Software
# 136  Technology                    Industrial Machinery/Components
# 6    Technology  Radio And Television Broadcasting And Communic...
# 101  Technology                              Electronic Components
# ..          ...                                                ...
# 96   Technology                    Industrial Machinery/Components
# 139  Technology                                       EDP Services
# 12   Technology                      Computer peripheral equipment
# 66   Technology            Computer Software: Prepackaged Software
# 149  Technology                                       EDP Services
#
#      float shares      Volume
# 42       809434.0  28451917.0
# 143    18631075.0    554167.0
# 136    10295755.0    525381.0
# 6       4148116.0    286406.0
# 101     3644134.0    271755.0
# ..            ...         ...
# 96       863990.0        35.0
# 139      835212.0        20.0
# 12      5424872.0        14.0
# 66       623346.0         5.0
# 149     2889328.0         1.0
#
# [154 rows x 7 columns]

# %%
from datetime import datetime
t = yf.Ticker("CRKN").news[0]["providerPublishTime"]
# print(time.ctime(time))
now = datetime.today().strftime('%Y-%m-%d %H:%M:%S').split(" ")[0]
# datetime.time(t)
1692970213-t
# now, 1692970213-t
published = datetime.fromtimestamp(yf.Ticker("CRKN").news[0]["providerPublishTime"]).strftime('%Y-%m-%d %H:%M:%S').split(" ")[0]
# now-published
datetime.fromtimestamp(yf.Ticker("CRKN").news[0]["providerPublishTime"]).strftime('%Y-%m-%d %H:%M:%S').split(" ")[0]==datetime.today().strftime('%Y-%m-%d %H:%M:%S').split(" ")[0]
# Out:
# False

# %%
import requests
from bs4 import BeautifulSoup as bs
from datetime import datetime
# sym = user_dataset.Symbol
article = []
published_today = []
for sym in user_dataset.Symbol:
    try:
        published_today.append(datetime.fromtimestamp(yf.Ticker("CRKN").news[0]["providerPublishTime"]).strftime('%Y-%m-%d %H:%M:%S').split(" ")[0]==datetime.today().strftime('%Y-%m-%d %H:%M:%S').split(" ")[0])
        url = yf.Ticker(sym).news[0]["link"]
        print(url)
        print(sym)
        data = requests.get(url)
        data = bs(data.content)
    
        article.append(data.find("div",{'class':'caas-body'}).text)
    except:
        published_today.append("")
        article.append("")
# data 
# data.div
user_dataset["Published today"] = published_today
user_dataset["Article"] = article
# Out:
# https://finance.yahoo.com/news/crown-electrokinetics-provides-second-quarter-132500302.html
# CRKN
# https://finance.yahoo.com/news/minerva-surgical-inc-utrs-reports-212516643.html
# UTRS
# https://finance.yahoo.com/news/tempo-automation-receives-nasdaq-notification-093000129.html
# TMPO
# https://finance.yahoo.com/news/ubiquiti-inc-reports-fourth-quarter-110500551.html
# UI
# https://finance.yahoo.com/news/orbital-infrastructure-group-inc-intends-030000483.html
# OIG
# https://finance.yahoo.com/m/9a23a84f-d151-35cd-a242-21a4bacfd308/growth-stock-climbing-too.html
# MSTR
# https://finance.yahoo.com/news/much-upside-left-backblaze-inc-135504198.html
# BLZE
# https://finance.yahoo.com/news/skywater-announces-appointment-retired-u-200500265.html
# SKYT
# https://finance.yahoo.com/news/81-stake-microcloud-hologram-inc-121326008.html
# HOLO
# https://finance.yahoo.com/news/downgrade-know-latest-peraso-inc-100136326.html
# PRSO
# https://finance.yahoo.com/news/near-intelligence-publishes-interactive-ebook-110000852.html
# NIR
# https://finance.yahoo.com/news/powerschool-holdings-nyse-pwsc-more-154540980.html
# PWSC
# https://finance.yahoo.com/news/beam-global-announces-record-second-200500454.html
# BEEM
# https://finance.yahoo.com/news/recruiter-com-group-hidden-value-154510077.html
# RCRT
# https://finance.yahoo.com/news/jared-wolfson-ceo-grom-social-120000478.html
# GROM
# https://finance.yahoo.com/news/trust-stamp-announces-proposed-action-131000638.html
# IDAI
# https://finance.yahoo.com/news/asure-software-inc-announces-closing-200100234.html
# ASUR
# https://finance.yahoo.com/news/auddia-inc-announces-filing-delayed-110000110.html
# AUUD
# https://finance.yahoo.com/news/tellenger-wins-seven-u-government-123000612.html
# WAVD
